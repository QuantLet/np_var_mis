# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import statsmodels.nonparametric.api as nparam
from statsmodels.nonparametric.kernel_regression import KernelReg
# Out:
# /Users/lilimatic/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv('moscow_apartment_listings.csv')

# %%
df = df[['price','lat','lon','footage','subway_dist_to_center']]

# %%
df = df[['price','footage']]

# %%
df = df.apply(lambda t: np.log(t))

# %%
df
# Out:
#            price   footage
# 0      15.894952  3.673766
# 1      15.789592  3.572346
# 2      16.147654  3.970292
# 3      15.955577  3.786460
# 4      16.012735  3.788725
# ...          ...       ...
# 12176  15.978834  3.589059
# 12177  16.061525  3.645450
# 12178  16.759950  4.021774
# 12179  16.642824  4.127134
# 12180  16.667950  3.777348
#
# [12181 rows x 2 columns]

# %%
df = df.sort_values(by=['footage'])

# %%
df = df.sample(n=1000,random_state=1)

# %%
len(df)
# Out:
# 1000

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'footage'}>]], dtype=object)

# %%
fig, ax = plt.subplots(1, 1,figsize=(20, 10))

plt.plot(df['footage'],df['price'],'o')

# %%
model = KernelReg(endog=[df.price],exog=[df.footage],reg_type='ll',var_type='c', bw='cv_ls')

# %%
fig, ax = plt.subplots(1, 1,figsize=(20, 10))

plt.plot(df['footage'],df['price'],'o')

# %%
model.bw
# Out:
# array([0.06738501])

# %%
fig, ax = plt.subplots(1, 1,figsize=(20, 10))

plt.plot(df['footage'],df['price'],'o')

#ax.plot(np.linspace(df['footage'].min(), df['footage'].max(), n),model.fit(np.linspace(-2, 2, n))[0] ,color= 'black', lw=2)
